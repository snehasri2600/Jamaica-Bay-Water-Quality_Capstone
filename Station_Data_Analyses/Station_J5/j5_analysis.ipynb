# %% [markdown]
# # Station J5 Analysis

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# Load cleaned dataset for station J5
j5_data = pd.read_csv('../../Station_Datasets/j5_data.csv')
display(j5_data.head())
# Out:
#   Sampling Location Sample Date  Top Sample Temperature (ºC)  \
# 0                J5  1995-06-14                        19.98
# 1                J5  1995-06-21                        21.62
# 2                J5  1995-07-13                        23.61
# 3                J5  1995-07-27                          NaN
# 4                J5  1995-08-22                        25.36
#
#    Winkler Method Top Dissolved Oxygen (mg/L)  Top Salinity  (psu)  Top PH  \
# 0                                        9.32                27.92    7.95
# 1                                        6.67                28.75    8.05
# 2                                        6.04                27.92    7.70
# 3                                        4.46                  NaN    7.56
# 4                                        7.52                28.62    7.87
#
#    Secchi Depth (ft)  Top Active Chlorophyll 'A' (µg/L)  \
# 0                NaN                              111.4
# 1                3.0                               61.9
# 2                4.0                               37.7
# 3                5.0                               23.0
# 4                3.5                               52.6
#
#    Total Phosphorus(mg/L)  Top Ammonium (mg/L)  \
# 0                    0.25                 0.11
# 1                    0.24                 0.14
# 2                    0.22                 0.26
# 3                    0.38                 0.30
# 4                    0.28                 0.17
#
#    Top Total Kjeldhal Nitrogen (mg/L)  Top Nitrate/Nitrite (mg/L)
# 0                                 NaN                       0.150
# 1                                 NaN                       0.052
# 2                                 NaN                       0.310
# 3                                 NaN                       0.270
# 4                                 NaN                       0.210

# %% [markdown]
# ## Data normalization and calculations

# %% [markdown]
# See the distribution of features across the dataset

# %%
# Create dataframe without sample date  and sampling location columns
columns_to_drop = ['Sampling Location','Sample Date']
j5_features = j5_data.drop(columns_to_drop, axis=1)

#Visualize histograms of all variables within j5_features
j5_features.hist(bins=50, figsize=(20, 15))
plt.show()

# %% [markdown]
# Some features were log-transformed in order to generate normal distribution. Since we want to see the yearly variance within stations, instead of clustering the stations, we will normalize the variables individually for each station.

# %%
j5_features_transformed = j5_features.copy()

# Define the list of columns to be log-transformed
log_transform_cols = [
    'Winkler Method Top Dissolved Oxygen (mg/L)',
    'Secchi Depth (ft)',
    "Top Active Chlorophyll 'A' (µg/L)",
    'Total Phosphorus(mg/L)',
    'Top Ammonium (mg/L)',
    'Top Total Kjeldhal Nitrogen (mg/L)',
    'Top Nitrate/Nitrite (mg/L)'
]

# Apply log1p transformation to the selected columns
for col in log_transform_cols:
    # For this specific dataset, we will proceed assuming non-negative values where log is appropriate.
    j5_features_transformed[col] = np.log(j5_features_transformed[col])

print("Data after log transformation:")
display(j5_features_transformed.head())

# Optionally, visualize histograms of the transformed columns to check distribution
j5_features_transformed.hist(bins=50, figsize=(20, 15))
plt.show()
# Out:
# Data after log transformation:
#    Top Sample Temperature (ºC)  Winkler Method Top Dissolved Oxygen (mg/L)  \
# 0                        19.98                                    2.232163
# 1                        21.62                                    1.897620
# 2                        23.61                                    1.798404
# 3                          NaN                                    1.495149
# 4                        25.36                                    2.017566
#
#    Top Salinity  (psu)  Top PH  Secchi Depth (ft)  \
# 0                27.92    7.95                NaN
# 1                28.75    8.05           1.098612
# 2                27.92    7.70           1.386294
# 3                  NaN    7.56           1.609438
# 4                28.62    7.87           1.252763
#
#    Top Active Chlorophyll 'A' (µg/L)  Total Phosphorus(mg/L)  \
# 0                           4.713127               -1.386294
# 1                           4.125520               -1.427116
# 2                           3.629660               -1.514128
# 3                           3.135494               -0.967584
# 4                           3.962716               -1.272966
#
#    Top Ammonium (mg/L)  Top Total Kjeldhal Nitrogen (mg/L)  \
# 0            -2.207275                                 NaN
# 1            -1.966113                                 NaN
# 2            -1.347074                                 NaN
# 3            -1.203973                                 NaN
# 4            -1.771957                                 NaN
#
#    Top Nitrate/Nitrite (mg/L)
# 0                   -1.897120
# 1                   -2.956512
# 2                   -1.171183
# 3                   -1.309333
# 4                   -1.560648

# %% [markdown]
# Scale all relevant features EXCEPT 'Sample Date' using StandardScaler

# %%
# Scale features
j5_features_scaled = StandardScaler().fit_transform(j5_features_transformed)

# Add scaled features back into the dataset WITH the year
j5_scaled_df = pd.DataFrame(j5_features_scaled, columns=j5_features_transformed.columns)
j5_scaled_df['Date'] = pd.to_datetime(j5_data['Sample Date']).values

display(j5_scaled_df)
# Out:
#      Top Sample Temperature (ºC)  Winkler Method Top Dissolved Oxygen (mg/L)  \
# 0                      -1.580696                                    0.989076
# 1                      -0.855869                                   -0.252970
# 2                       0.023646                                   -0.621325
# 3                            NaN                                   -1.747211
# 4                       0.797089                                    0.192351
# ..                           ...                                         ...
# 412                     0.588237                                   -1.191587
# 413                     0.090339                                   -0.047259
# 414                    -0.275080                                    1.016857
# 415                    -0.747278                                    1.627937
# 416                    -0.315829                                    0.289802
#
#      Top Salinity  (psu)    Top PH  Secchi Depth (ft)  \
# 0               0.647130  0.311559                NaN
# 1               1.111043  0.665682          -0.493827
# 2               0.647130 -0.573749           0.488806
# 3                    NaN -1.069522           1.250995
# 4               1.038382  0.028260           0.032704
# ..                   ...       ...                ...
# 412            -0.381919 -0.361276          -0.493827
# 413            -0.182017  0.382383          -0.493827
# 414            -0.162929  1.161455          -1.116581
# 415            -0.025125  1.940526          -1.878770
# 416            -0.063747  1.055218          -0.493827
#
#      Top Active Chlorophyll 'A' (µg/L)  Total Phosphorus(mg/L)  \
# 0                             1.815941               -0.013410
# 1                             1.034808               -0.144705
# 2                             0.375638               -0.424559
# 3                            -0.281279                1.333281
# 4                             0.818385                0.351087
# ..                                 ...                     ...
# 412                           0.314301                1.194925
# 413                           0.766853                0.173999
# 414                           0.904021               -0.845690
# 415                                NaN                     NaN
# 416                           1.070824               -0.604958
#
#      Top Ammonium (mg/L)  Top Total Kjeldhal Nitrogen (mg/L)  \
# 0              -0.423765                                 NaN
# 1              -0.183662                                 NaN
# 2               0.432656                                 NaN
# 3               0.575128                                 NaN
# 4               0.009640                                 NaN
# ..                   ...                                 ...
# 412             1.079718                            0.233462
# 413             0.397582                           -0.752718
# 414            -0.623553                           -0.043486
# 415                  NaN                                 NaN
# 416            -0.069563                           -0.022151
#
#      Top Nitrate/Nitrite (mg/L)       Date
# 0                      0.338539 1995-06-14
# 1                     -0.812356 1995-06-21
# 2                      1.127178 1995-07-13
# 3                      0.977095 1995-07-27
# 4                      0.704074 1995-08-22
# ..                          ...        ...
# 412                    0.286621 2024-08-20
# 413                    0.286621 2024-08-27
# 414                    0.764444 2024-09-04
# 415                         NaN 2024-09-10
# 416                    0.309176 2024-09-17
#
# [417 rows x 11 columns]

# %% [markdown]
# Take yearly means

# %%
# Take yearly means
j5_yearly_means = j5_scaled_df.groupby(j5_scaled_df['Date'].dt.year).mean()
display(j5_yearly_means.head())
# Out:
#       Top Sample Temperature (ºC)  Winkler Method Top Dissolved Oxygen (mg/L)  \
# Date
# 1995                    -0.426529                                   -0.302098
# 1996                    -0.391361                                   -0.249350
# 1997                    -0.544282                                    0.132118
# 1998                    -0.512117                                    0.304791
# 1999                     0.068285                                   -0.224683
#
#       Top Salinity  (psu)    Top PH  Secchi Depth (ft)  \
# Date
# 1995             0.831577 -0.184214           0.501041
# 1996            -0.482470 -0.679986           0.426916
# 1997            -0.046411 -0.163557           0.518520
# 1998            -0.252129  0.550592           0.220134
# 1999             0.587324 -0.881837           0.371684
#
#       Top Active Chlorophyll 'A' (µg/L)  Total Phosphorus(mg/L)  \
# Date
# 1995                           0.517611                0.209781
# 1996                           0.196988               -0.461200
# 1997                           0.749968                0.272071
# 1998                           0.271897               -0.581631
# 1999                           0.138592                0.304725
#
#       Top Ammonium (mg/L)  Top Total Kjeldhal Nitrogen (mg/L)  \
# Date
# 1995             0.205633                                 NaN
# 1996             0.560452                            0.228825
# 1997             0.253393                            0.470263
# 1998            -0.552567                            0.623439
# 1999             0.023275                            0.913765
#
#       Top Nitrate/Nitrite (mg/L)                       Date
# Date
# 1995                    0.744757 1995-08-03 21:00:00.000000
# 1996                    0.876008 1996-08-07 12:00:00.000000
# 1997                    0.587384 1997-07-23 22:00:00.000000
# 1998                    0.551057 1998-07-20 13:05:27.272727
# 1999                    0.379860 1999-07-24 09:36:00.000000

# %%
# Check to ensure all columns exist correctly in the yearly means dataframe
print(j5_yearly_means.columns.tolist)
# Out:
# <bound method IndexOpsMixin.tolist of Index(['Top Sample Temperature (ºC)',
#        'Winkler Method Top Dissolved Oxygen (mg/L)', 'Top Salinity  (psu)',
#        'Top PH', 'Secchi Depth (ft)', 'Top Active Chlorophyll 'A' (µg/L)',
#        'Total Phosphorus(mg/L)', 'Top Ammonium (mg/L)',
#        'Top Total Kjeldhal Nitrogen (mg/L)', 'Top Nitrate/Nitrite (mg/L)',
#        'Date'],
#       dtype='str')>

# %% [markdown]
# ## PCA and PCA Visualizations

# %% [markdown]
# Drop the date column before running PCA on the features

# %%
#Drop date before PCA
feature_means = j5_yearly_means[[
    'Top Sample Temperature (ºC)',
    'Winkler Method Top Dissolved Oxygen (mg/L)',
    'Top Salinity  (psu)',
    'Top PH',
    'Secchi Depth (ft)',
    'Top Active Chlorophyll \'A\' (µg/L)',
    'Total Phosphorus(mg/L)',
    'Top Ammonium (mg/L)',
    'Top Total Kjeldhal Nitrogen (mg/L)',
    'Top Nitrate/Nitrite (mg/L)'
]]

print(feature_means.columns.tolist)
# Out:
# <bound method IndexOpsMixin.tolist of Index(['Top Sample Temperature (ºC)',
#        'Winkler Method Top Dissolved Oxygen (mg/L)', 'Top Salinity  (psu)',
#        'Top PH', 'Secchi Depth (ft)', 'Top Active Chlorophyll 'A' (µg/L)',
#        'Total Phosphorus(mg/L)', 'Top Ammonium (mg/L)',
#        'Top Total Kjeldhal Nitrogen (mg/L)', 'Top Nitrate/Nitrite (mg/L)'],
#       dtype='str')>

# %%
# Checking for null values in the feature_means dataframe
print(feature_means.isnull().sum())
# Out:
# Top Sample Temperature (ºC)                   0
# Winkler Method Top Dissolved Oxygen (mg/L)    0
# Top Salinity  (psu)                           0
# Top PH                                        0
# Secchi Depth (ft)                             0
# Top Active Chlorophyll 'A' (µg/L)             0
# Total Phosphorus(mg/L)                        0
# Top Ammonium (mg/L)                           0
# Top Total Kjeldhal Nitrogen (mg/L)            1
# Top Nitrate/Nitrite (mg/L)                    0
# dtype: int64

# %% [markdown]
# There is one null value in the 'Total Kjeldhal Nitrogen (mg/L)' column. I want to know where the missing value is.

# %%
print("Row(s) with missing Top Total Kjeldhal Nitrogen (mg/L):")
display(feature_means[feature_means['Top Total Kjeldhal Nitrogen (mg/L)'].isnull()])
# Out:
# Row(s) with missing Top Total Kjeldhal Nitrogen (mg/L):
#       Top Sample Temperature (ºC)  Winkler Method Top Dissolved Oxygen (mg/L)  \
# Date
# 1995                    -0.426529                                   -0.302098
#
#       Top Salinity  (psu)    Top PH  Secchi Depth (ft)  \
# Date
# 1995             0.831577 -0.184214           0.501041
#
#       Top Active Chlorophyll 'A' (µg/L)  Total Phosphorus(mg/L)  \
# Date
# 1995                           0.517611                0.209781
#
#       Top Ammonium (mg/L)  Top Total Kjeldhal Nitrogen (mg/L)  \
# Date
# 1995             0.205633                                 NaN
#
#       Top Nitrate/Nitrite (mg/L)
# Date
# 1995                    0.744757

# %% [markdown]
# Since there is only one row with missing values, and this row is the first in the dataframe, we will drop it for PCA analysis.

# %%
#Import libraries
import matplotlib.patches as mpatches
from matplotlib.patches import FancyArrowPatch

# %%
# Initialize PCA and drop extra row
pca = PCA(n_components=2)
# Drop rows with NaN values before PCA
feature_means = feature_means.dropna()

# %%
# Run PCA on feature means
feature_means_pca = pca.fit_transform(feature_means)  # shape: (n_samples, 2)
loadings = pca.components_.T                          # shape: (n_features, 2)

# %%
# Ensuring the index is explicitly set to the years for plotting
feature_means_pca_df = pd.DataFrame(feature_means_pca, columns=['PC1', 'PC2'], index=feature_means.index)
display(feature_means_pca_df.head())
# Out:
#            PC1       PC2
# Date
# 1996  1.179403 -0.522944
# 1997  0.948920  0.157547
# 1998  0.753495  0.098130
# 1999  0.998931  0.738969
# 2000  0.362941 -0.284456

# %%
# See the explained variance ratio to understand how much variance is captured by the first two principal components
explained_variance = pca.explained_variance_ratio_
print(f"Explained variance ratio by PC1 and PC2: {explained_variance}")
# Out:
# Explained variance ratio by PC1 and PC2: [0.37375628 0.22607579]

# %% [markdown]
# Now we have PC1 and PC2, along with the year. We now want to generate the plot to visualize the PCA.

# %%
#Generating a list of shorter names for the columns, so that the final visualization is less cluttered.
feature_names_short = [
    'Temp (°C)',
    'DO (mg/L)',
    'Salinity (psu)',
    'pH',
    'Secchi (ft)',
    'ChlA (µg/L)',
    'P (mg/L)',
    'NH4 (mg/L)',
    'TKN (mg/L)',
    'NO3+NO2 (mg/L)'
]

# %%
# Generating the plot
fig, ax = plt.subplots(figsize=(10, 8))

# --- Plot yearly points ---
ax.scatter(feature_means_pca_df['PC1'], feature_means_pca_df['PC2'], color='lightblue', zorder=5, s=60)
for _, row in feature_means_pca_df.iterrows():
    ax.annotate(str(int(row.name)), xy=(row['PC1'], row['PC2']),
                xytext=(5, 5), textcoords='offset points',
                fontsize=9, color='lightblue', fontweight='bold')

# --- Scale factor for arrows (tune as needed) ---
scale = 2.0

# --- Plot loading arrows ---
for i, name in enumerate(feature_names_short):
    x, y = loadings[i, 0] * scale, loadings[i, 1] * scale
    ax.annotate('', xy=(x, y), xytext=(0, 0),
                arrowprops=dict(arrowstyle='->', color='navy', lw=1.8))
    ax.text(x * 1.1, y * 1.1, name, fontsize=9, color='navy', fontstyle='italic')

# --- Secondary axes for loading scale ---
ax_top = ax.twiny()  # shares y-axis, adds top x-axis
ax_right = ax.twinx()  # shares x-axis, adds right y-axis

# Set limits divided by scale factor to show true loading values
ax_top.set_xlim(ax.get_xlim()[0] / scale, ax.get_xlim()[1] / scale)
ax_right.set_ylim(ax.get_ylim()[0] / scale, ax.get_ylim()[1] / scale)

# Style the top axis
ax_top.set_xlabel('PC1 Loadings', fontsize=10, color='navy', labelpad=8)
ax_top.tick_params(axis='x', colors='navy', labelsize=8)

# Style the right axis
ax_right.set_ylabel('PC2 Loadings', fontsize=10, color='navy', labelpad=8)
ax_right.tick_params(axis='y', colors='navy', labelsize=8)

# --- Reference lines ---
ax.axhline(0, color='gray', linewidth=0.8, linestyle='--')
ax.axvline(0, color='gray', linewidth=0.8, linestyle='--')

# --- Labels ---
ax.set_xlabel(f'PCA 1 (Explained Variance: {explained_variance[0] * 100:.2f}%)', fontsize=12)
ax.set_ylabel(f'PCA 2 (Explained Variance: {explained_variance[1] * 100:.2f}%)', fontsize=12)
ax.set_title('PCA Biplot – Jamaica Bay Water Quality (Station J5)', fontsize=13)

# --- Legend ---
arrow_patch = mpatches.FancyArrow(0, 0, 0, 0, color='darkblue')
point_patch = mpatches.Patch(color='lightblue', label='Calendar Year')
ax.legend(handles=[
    plt.Line2D([0], [0], color='darkblue', marker=r'$\rightarrow$',
               markersize=12, label='Water Quality Parameter', linestyle='None'),
    plt.Line2D([0], [0], marker='o', color='lightblue',
               markersize=8, label='Calendar Year', linestyle='None')
], loc='upper right')

plt.tight_layout()
plt.savefig('jamaica_bay_pca_j5.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## K-Means Clustering

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
# plot the elbow visualization
inertiaVals1 = {}

for k in range(1, 15):
    kmeansK1 = KMeans(n_clusters=k, max_iter=1000).fit(feature_means)
    inertiaVals1[k] = kmeansK1.inertia_
plt.figure()
plt.plot(list(inertiaVals1.keys()), list(inertiaVals1.values()))
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
# Find optimal number of clusters
for k in range(2, 7):
    km = KMeans(n_clusters=k, random_state=42)
    labels = km.fit_predict(feature_means)
    score = silhouette_score(feature_means, labels)
    print(f"k={k}, silhouette score: {score:.3f}")
# Out:
# k=2, silhouette score: 0.242
# k=3, silhouette score: 0.198
# k=4, silhouette score: 0.150
# k=5, silhouette score: 0.157
# k=6, silhouette score: 0.143

# %% [markdown]
# Two and three clusters seem ideal. I will start by visualizing those.

# %%
# Use best k
kmeans = KMeans(n_clusters=2, random_state=42)
feature_means_pca_df['Cluster'] = kmeans.fit_predict(feature_means)
print(feature_means_pca_df[['Cluster']].sort_values('Cluster'))
# Out:
#       Cluster
# Date
# 1996        0
# 1997        0
# 1998        0
# 1999        0
# 2000        0
# 2001        0
# 2002        0
# 2003        0
# 2004        0
# 2005        0
# 2006        0
# 2007        0
# 2008        0
# 2009        0
# 2010        0
# 2012        0
# 2013        0
# 2011        1
# 2014        1
# 2015        1
# 2016        1
# 2017        1
# 2018        1
# 2019        1
# 2020        1
# 2021        1
# 2022        1
# 2023        1
# 2024        1

# %%
# Generating the plot – colored by cluster
fig, ax = plt.subplots(figsize=(10, 8))

cluster_colors = {0: 'lightblue', 1: 'lightcoral'}

# --- Plot yearly points ---
for idx, row in feature_means_pca_df.iterrows():
    color = cluster_colors[row['Cluster']]
    ax.scatter(row['PC1'], row['PC2'], color=color, zorder=5, s=60)
    ax.annotate(str(int(idx)), xy=(row['PC1'], row['PC2']),
                xytext=(5, 5), textcoords='offset points',
                fontsize=9, color=color, fontweight='bold')

# --- Scale factor for arrows ---
scale = 2.0

# --- Plot loading arrows ---
for i, name in enumerate(feature_names_short):
    x, y = loadings[i, 0] * scale, loadings[i, 1] * scale
    ax.annotate('', xy=(x, y), xytext=(0, 0),
                arrowprops=dict(arrowstyle='->', color='navy', lw=1.8))
    ax.text(x * 1.1, y * 1.1, name, fontsize=9, color='navy', fontstyle='italic')

# --- Secondary axes for loading scale ---
ax_top = ax.twiny()  # shares y-axis, adds top x-axis
ax_right = ax.twinx()  # shares x-axis, adds right y-axis

# Set limits divided by scale factor to show true loading values
ax_top.set_xlim(ax.get_xlim()[0] / scale, ax.get_xlim()[1] / scale)
ax_right.set_ylim(ax.get_ylim()[0] / scale, ax.get_ylim()[1] / scale)

# Style the top axis
ax_top.set_xlabel('PC1 Loadings', fontsize=10, color='navy', labelpad=8)
ax_top.tick_params(axis='x', colors='navy', labelsize=8)

# Style the right axis
ax_right.set_ylabel('PC2 Loadings', fontsize=10, color='navy', labelpad=8)
ax_right.tick_params(axis='y', colors='navy', labelsize=8)

# --- Reference lines ---
ax.axhline(0, color='gray', linewidth=0.8, linestyle='--')
ax.axvline(0, color='gray', linewidth=0.8, linestyle='--')

# --- Labels ---
ax.set_xlabel(f'PCA 1 (Explained Variance: {explained_variance[0] * 100:.2f}%)', fontsize=12)
ax.set_ylabel(f'PCA 2 (Explained Variance: {explained_variance[1] * 100:.2f}%)', fontsize=12)
ax.set_title('PCA Biplot – Jamaica Bay Water Quality (Station J5)', fontsize=13)

# --- Legend ---
ax.legend(handles=[
    plt.Line2D([0], [0], color='darkblue', marker=r'$\rightarrow$',
               markersize=12, label='Water Quality Parameter', linestyle='None'),
    plt.Line2D([0], [0], marker='o', color='lightblue',
               markersize=8, label='Calendar Year (Cluster 0)', linestyle='None'),
    plt.Line2D([0], [0], marker='o', color='lightcoral',
               markersize=8, label='Calendar Year (Cluster 1)', linestyle='None'),
], loc='upper right')

plt.tight_layout()
plt.savefig('jamaica_bay_pca_j5_2clusters.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Doing the same with 3 clusters

# %%
# Use best k
kmeans1 = KMeans(n_clusters=3, random_state=42)
feature_means_pca_df['Cluster'] = kmeans1.fit_predict(feature_means)
print(feature_means_pca_df[['Cluster']].sort_values('Cluster'))
# Out:
#       Cluster
# Date
# 1996        0
# 1997        0
# 1998        0
# 2000        0
# 2003        0
# 2006        0
# 2005        0
# 2004        0
# 2009        0
# 2007        0
# 2013        0
# 2012        0
# 2015        1
# 2014        1
# 2011        1
# 2016        1
# 2020        1
# 2021        1
# 2022        1
# 2023        1
# 2024        1
# 2017        1
# 2018        1
# 2019        1
# 2010        2
# 2008        2
# 2001        2
# 2002        2
# 1999        2

# %%
# PCA biplot with 3 clusters, colored in shades of green
fig, ax = plt.subplots(figsize=(10, 8))

cluster_colors = {0: 'lightblue', 1: 'lightcoral', 2: 'green'}

# --- Plot yearly points ---
for idx, row in feature_means_pca_df.iterrows():
    color = cluster_colors[row['Cluster']]
    ax.scatter(row['PC1'], row['PC2'], color=color, zorder=5, s=60)
    ax.annotate(str(int(idx)), xy=(row['PC1'], row['PC2']),
                xytext=(5, 5), textcoords='offset points',
                fontsize=9, color=color, fontweight='bold')

# --- Scale factor for arrows ---
scale = 2.0

# --- Plot loading arrows ---
for i, name in enumerate(feature_names_short):
    x, y = loadings[i, 0] * scale, loadings[i, 1] * scale
    ax.annotate('', xy=(x, y), xytext=(0, 0),
                arrowprops=dict(arrowstyle='->', color='navy', lw=1.8))
    ax.text(x * 1.1, y * 1.1, name, fontsize=9, color='navy', fontstyle='italic')

# --- Secondary axes for loading scale ---
ax_top = ax.twiny()  # shares y-axis, adds top x-axis
ax_right = ax.twinx()  # shares x-axis, adds right y-axis

# Set limits divided by scale factor to show true loading values
ax_top.set_xlim(ax.get_xlim()[0] / scale, ax.get_xlim()[1] / scale)
ax_right.set_ylim(ax.get_ylim()[0] / scale, ax.get_ylim()[1] / scale)

# Style the top axis
ax_top.set_xlabel('PC1 Loadings', fontsize=10, color='navy', labelpad=8)
ax_top.tick_params(axis='x', colors='navy', labelsize=8)

# Style the right axis
ax_right.set_ylabel('PC2 Loadings', fontsize=10, color='navy', labelpad=8)
ax_right.tick_params(axis='y', colors='navy', labelsize=8)

# --- Reference lines ---
ax.axhline(0, color='gray', linewidth=0.8, linestyle='--')
ax.axvline(0, color='gray', linewidth=0.8, linestyle='--')

# --- Labels ---
ax.set_xlabel(f'PCA 1 (Explained Variance: {explained_variance[0] * 100:.2f}%)', fontsize=12)
ax.set_ylabel(f'PCA 2 (Explained Variance: {explained_variance[1] * 100:.2f}%)', fontsize=12)
ax.set_title('PCA Biplot – Jamaica Bay Water Quality (Station J5)', fontsize=13)

# --- Legend ---
ax.legend(handles=[
    plt.Line2D([0], [0], color='darkblue', marker=r'$\rightarrow$',
               markersize=12, label='Water Quality Parameter', linestyle='None'),
    plt.Line2D([0], [0], marker='o', color='lightblue',
               markersize=8, label='Cluster 0', linestyle='None'),
    plt.Line2D([0], [0], marker='o', color='lightcoral',
               markersize=8, label='Cluster 1', linestyle='None'),
    plt.Line2D([0], [0], marker='o', color='green',
               markersize=8, label='Cluster 2', linestyle='None'),
], loc='upper right')

plt.tight_layout()
plt.savefig('jamaica_bay_pca_j5_3clusters.png', dpi=300, bbox_inches='tight')
plt.show()

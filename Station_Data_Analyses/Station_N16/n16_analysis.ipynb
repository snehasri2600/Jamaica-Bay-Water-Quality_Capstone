# %% [markdown]
# # Station N16 Analysis

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# Load cleaned dataset for station N16
n16_data = pd.read_csv('../../Station_Datasets/n16_data.csv')
display(n16_data.head())
# Out:
#   Sampling Location Sample Date  Top Sample Temperature (ºC)  \
# 0               N16  1995-06-21                        16.10
# 1               N16  1995-07-13                        20.34
# 2               N16  1995-07-27                        19.05
# 3               N16  1995-08-22                        24.52
# 4               N16  1995-08-29                        22.30
#
#    Winkler Method Top Dissolved Oxygen (mg/L)  Top Salinity  (psu)  Top PH  \
# 0                                        8.32                30.94    7.85
# 1                                        8.44                30.56    7.94
# 2                                        5.61                31.47    7.61
# 3                                        8.45                29.36    7.99
# 4                                        8.42                30.73    8.21
#
#    Secchi Depth (ft)  Top Active Chlorophyll 'A' (µg/L)  \
# 0                7.0                               23.8
# 1                6.0                                9.3
# 2                9.0                               83.8
# 3                4.5                               38.0
# 4                5.5                               14.3
#
#    Total Phosphorus(mg/L)  Top Ammonium (mg/L)  \
# 0                   0.070                0.007
# 1                   0.065                0.110
# 2                   0.100                0.054
# 3                   0.110                0.026
# 4                   0.075                0.010
#
#    Top Total Kjeldhal Nitrogen (mg/L)  Top Nitrate/Nitrite (mg/L)
# 0                                 NaN                       0.009
# 1                                 NaN                       0.009
# 2                                 NaN                       0.011
# 3                                 NaN                       0.071
# 4                                 NaN                       0.005

# %% [markdown]
# ## Data normalization and calculations

# %% [markdown]
# See the distribution of features across the dataset

# %%
# Create dataframe without sample date  and sampling location columns
columns_to_drop = ['Sampling Location','Sample Date']
n16_features = n16_data.drop(columns_to_drop, axis=1)

#Visualize histograms of all variables within n16_features
n16_features.hist(bins=50, figsize=(20, 15))
plt.show()

# %% [markdown]
# Some features were log-transformed in order to generate normal distribution. Since we want to see the yearly variance within stations, instead of clustering the stations, we will normalize the variables individually for each station.

# %%
n16_features_transformed = n16_features.copy()

# Define the list of columns to be log-transformed
log_transform_cols = [
    'Winkler Method Top Dissolved Oxygen (mg/L)',
    'Secchi Depth (ft)',
    "Top Active Chlorophyll 'A' (µg/L)",
    'Total Phosphorus(mg/L)',
    'Top Ammonium (mg/L)',
    'Top Total Kjeldhal Nitrogen (mg/L)',
    'Top Nitrate/Nitrite (mg/L)'
]

# Apply log1p transformation to the selected columns
for col in log_transform_cols:
    # For this specific dataset, we will proceed assuming non-negative values where log is appropriate.
    n16_features_transformed[col] = np.log(n16_features_transformed[col])

print("Data after log transformation:")
display(n16_features_transformed.head())

# Optionally, visualize histograms of the transformed columns to check distribution
n16_features_transformed.hist(bins=50, figsize=(20, 15))
plt.show()
# Out:
# Data after log transformation:
#    Top Sample Temperature (ºC)  Winkler Method Top Dissolved Oxygen (mg/L)  \
# 0                        16.10                                    2.118662
# 1                        20.34                                    2.132982
# 2                        19.05                                    1.724551
# 3                        24.52                                    2.134166
# 4                        22.30                                    2.130610
#
#    Top Salinity  (psu)  Top PH  Secchi Depth (ft)  \
# 0                30.94    7.85           1.945910
# 1                30.56    7.94           1.791759
# 2                31.47    7.61           2.197225
# 3                29.36    7.99           1.504077
# 4                30.73    8.21           1.704748
#
#    Top Active Chlorophyll 'A' (µg/L)  Total Phosphorus(mg/L)  \
# 0                           3.169686               -2.659260
# 1                           2.230014               -2.733368
# 2                           4.428433               -2.302585
# 3                           3.637586               -2.207275
# 4                           2.660260               -2.590267
#
#    Top Ammonium (mg/L)  Top Total Kjeldhal Nitrogen (mg/L)  \
# 0            -4.961845                                 NaN
# 1            -2.207275                                 NaN
# 2            -2.918771                                 NaN
# 3            -3.649659                                 NaN
# 4            -4.605170                                 NaN
#
#    Top Nitrate/Nitrite (mg/L)
# 0                   -4.710531
# 1                   -4.710531
# 2                   -4.509860
# 3                   -2.645075
# 4                   -5.298317

# %% [markdown]
# Scale all relevant features EXCEPT 'Sample Date' using StandardScaler

# %%
# Scale features
n16_features_scaled = StandardScaler().fit_transform(n16_features_transformed)

# Add scaled features back into the dataset WITH the year
n16_scaled_df = pd.DataFrame(n16_features_scaled, columns=n16_features_transformed.columns)
n16_scaled_df['Date'] = pd.to_datetime(n16_data['Sample Date']).values

display(n16_scaled_df)
# Out:
#      Top Sample Temperature (ºC)  Winkler Method Top Dissolved Oxygen (mg/L)  \
# 0                      -1.688296                                    0.706862
# 1                      -0.076749                                    0.793410
# 2                      -0.567054                                   -1.675076
# 3                       1.511994                                    0.800567
# 4                       0.668212                                    0.779071
# ..                           ...                                         ...
# 381                     0.491683                                    0.507476
# 382                     0.237047                                   -0.017723
# 383                     0.300464                                   -0.647227
# 384                     0.388928                                    0.167759
# 385                     0.111221                                   -0.328592
#
#      Top Salinity  (psu)    Top PH  Secchi Depth (ft)  \
# 0               0.796939 -0.112778          -0.218601
# 1               0.531451  0.345296          -0.577548
# 2               1.167225 -1.334309           0.366595
# 3              -0.306933  0.599782          -1.247428
# 4               0.650222  1.719518          -0.780157
# ..                   ...       ...                ...
# 381            -0.049409  0.956061          -0.577548
# 382             0.067545  0.752473           0.366595
# 383            -0.577556  0.548884          -0.218601
# 384             0.178142  1.312341          -0.577548
# 385             0.048298  0.854267          -1.247428
#
#      Top Active Chlorophyll 'A' (µg/L)  Total Phosphorus(mg/L)  \
# 0                             1.451572                0.037192
# 1                             0.482057               -0.087281
# 2                             2.750298                0.636274
# 3                             1.934333                0.796360
# 4                             0.925967                0.153075
# ..                                 ...                     ...
# 381                           1.416295                0.175322
# 382                           0.260113               -0.430086
# 383                           1.079846                1.294759
# 384                           0.692122               -0.430086
# 385                                NaN                     NaN
#
#      Top Ammonium (mg/L)  Top Total Kjeldhal Nitrogen (mg/L)  \
# 0              -2.024231                                 NaN
# 1               0.680512                                 NaN
# 2              -0.018114                                 NaN
# 3              -0.735780                                 NaN
# 4              -1.674008                                 NaN
# ..                   ...                                 ...
# 381            -0.197138                            0.284636
# 382             0.133248                            0.220417
# 383            -0.197138                            0.083940
# 384            -0.197138                            0.239023
# 385                  NaN                                 NaN
#
#      Top Nitrate/Nitrite (mg/L)       Date
# 0                     -1.080753 1995-06-21
# 1                     -1.080753 1995-07-13
# 2                     -0.866787 1995-07-27
# 3                      1.121551 1995-08-22
# 4                     -1.707484 1995-08-29
# ..                          ...        ...
# 381                   -0.284031 2024-08-06
# 382                    0.202990 2024-08-13
# 383                    0.561755 2024-08-27
# 384                   -0.284031 2024-09-04
# 385                         NaN 2024-09-10
#
# [386 rows x 11 columns]

# %% [markdown]
# Take yearly means

# %%
# Take yearly means
n16_yearly_means = n16_scaled_df.groupby(n16_scaled_df['Date'].dt.year).mean()
display(n16_yearly_means.head())
# Out:
#       Top Sample Temperature (ºC)  Winkler Method Top Dissolved Oxygen (mg/L)  \
# Date
# 1995                     0.077999                                    0.106381
# 1996                    -0.420723                                   -0.016284
# 1997                    -0.451647                                    0.112979
# 1998                    -0.312822                                    0.058132
# 1999                     0.010670                                   -0.027850
#
#       Top Salinity  (psu)    Top PH  Secchi Depth (ft)  \
# Date
# 1995             0.533447  0.243502          -0.550057
# 1996            -0.515530 -0.294554          -0.071764
# 1997            -0.047161 -0.469058           0.395248
# 1998            -0.691968  0.529798           0.884464
# 1999             0.532848 -1.395386           0.568688
#
#       Top Active Chlorophyll 'A' (µg/L)  Total Phosphorus(mg/L)  \
# Date
# 1995                           1.399744                0.477055
# 1996                           0.397187                0.247922
# 1997                           0.623068                0.178035
# 1998                          -0.141589               -0.434126
# 1999                           0.386787                0.176438
#
#       Top Ammonium (mg/L)  Top Total Kjeldhal Nitrogen (mg/L)  \
# Date
# 1995            -0.339809                                 NaN
# 1996             0.153252                            0.160032
# 1997            -0.287377                           -0.178284
# 1998            -0.330763                            0.565762
# 1999            -0.162519                            0.531281
#
#       Top Nitrate/Nitrite (mg/L)                       Date
# Date
# 1995                   -0.256763 1995-08-11 03:25:42.857142
# 1996                    0.520084 1996-08-07 12:00:00.000000
# 1997                   -0.124603 1997-07-23 22:00:00.000000
# 1998                   -0.325356 1998-07-20 13:05:27.272727
# 1999                   -0.222965 1999-07-24 09:36:00.000000

# %%
# Check to ensure all columns exist correctly in the yearly means dataframe
print(n16_yearly_means.columns.tolist)
# Out:
# <bound method IndexOpsMixin.tolist of Index(['Top Sample Temperature (ºC)',
#        'Winkler Method Top Dissolved Oxygen (mg/L)', 'Top Salinity  (psu)',
#        'Top PH', 'Secchi Depth (ft)', 'Top Active Chlorophyll 'A' (µg/L)',
#        'Total Phosphorus(mg/L)', 'Top Ammonium (mg/L)',
#        'Top Total Kjeldhal Nitrogen (mg/L)', 'Top Nitrate/Nitrite (mg/L)',
#        'Date'],
#       dtype='str')>

# %% [markdown]
# ## PCA and PCA Visualizations

# %% [markdown]
# Drop the date column before running PCA on the features

# %%
#Drop date before PCA
feature_means = n16_yearly_means[[
    'Top Sample Temperature (ºC)',
    'Winkler Method Top Dissolved Oxygen (mg/L)',
    'Top Salinity  (psu)',
    'Top PH',
    'Secchi Depth (ft)',
    'Top Active Chlorophyll \'A\' (µg/L)',
    'Total Phosphorus(mg/L)',
    'Top Ammonium (mg/L)',
    'Top Total Kjeldhal Nitrogen (mg/L)',
    'Top Nitrate/Nitrite (mg/L)'
]]

print(feature_means.columns.tolist)
# Out:
# <bound method IndexOpsMixin.tolist of Index(['Top Sample Temperature (ºC)',
#        'Winkler Method Top Dissolved Oxygen (mg/L)', 'Top Salinity  (psu)',
#        'Top PH', 'Secchi Depth (ft)', 'Top Active Chlorophyll 'A' (µg/L)',
#        'Total Phosphorus(mg/L)', 'Top Ammonium (mg/L)',
#        'Top Total Kjeldhal Nitrogen (mg/L)', 'Top Nitrate/Nitrite (mg/L)'],
#       dtype='str')>

# %%
# Checking for null values in the feature_means dataframe
print(feature_means.isnull().sum())
# Out:
# Top Sample Temperature (ºC)                   0
# Winkler Method Top Dissolved Oxygen (mg/L)    0
# Top Salinity  (psu)                           0
# Top PH                                        0
# Secchi Depth (ft)                             0
# Top Active Chlorophyll 'A' (µg/L)             0
# Total Phosphorus(mg/L)                        0
# Top Ammonium (mg/L)                           0
# Top Total Kjeldhal Nitrogen (mg/L)            1
# Top Nitrate/Nitrite (mg/L)                    0
# dtype: int64

# %% [markdown]
# There is one null value in the 'Total Kjeldhal Nitrogen (mg/L)' column. I want to know where the missing value is.

# %%
print("Row(s) with missing Top Total Kjeldhal Nitrogen (mg/L):")
display(feature_means[feature_means['Top Total Kjeldhal Nitrogen (mg/L)'].isnull()])
# Out:
# Row(s) with missing Top Total Kjeldhal Nitrogen (mg/L):
#       Top Sample Temperature (ºC)  Winkler Method Top Dissolved Oxygen (mg/L)  \
# Date
# 1995                     0.077999                                    0.106381
#
#       Top Salinity  (psu)    Top PH  Secchi Depth (ft)  \
# Date
# 1995             0.533447  0.243502          -0.550057
#
#       Top Active Chlorophyll 'A' (µg/L)  Total Phosphorus(mg/L)  \
# Date
# 1995                           1.399744                0.477055
#
#       Top Ammonium (mg/L)  Top Total Kjeldhal Nitrogen (mg/L)  \
# Date
# 1995            -0.339809                                 NaN
#
#       Top Nitrate/Nitrite (mg/L)
# Date
# 1995                   -0.256763

# %% [markdown]
# Since there is only one row with missing values, and this row is the first in the dataframe, we will drop it for PCA analysis.

# %%
#Import libraries
import matplotlib.patches as mpatches
from matplotlib.patches import FancyArrowPatch

# %%
# Initialize PCA and drop extra row
pca = PCA(n_components=2)
# Drop rows with NaN values before PCA
feature_means = feature_means.dropna()

# %%
# Run PCA on feature means
feature_means_pca = pca.fit_transform(feature_means)  # shape: (n_samples, 2)
loadings = pca.components_.T                          # shape: (n_features, 2)

# %%
# Ensuring the index is explicitly set to the years for plotting
feature_means_pca_df = pd.DataFrame(feature_means_pca, columns=['PC1', 'PC2'], index=feature_means.index)
display(feature_means_pca_df.head())
# Out:
#            PC1       PC2
# Date
# 1996 -0.023091 -0.664570
# 1997  0.424936 -0.217355
# 1998  0.476921 -0.548726
# 1999  1.179237  0.285129
# 2000  1.027268 -0.280192

# %%
# See the explained variance ratio to understand how much variance is captured by the first two principal components
explained_variance = pca.explained_variance_ratio_
print(f"Explained variance ratio by PC1 and PC2: {explained_variance}")
# Out:
# Explained variance ratio by PC1 and PC2: [0.28199739 0.24469079]

# %% [markdown]
# Now we have PC1 and PC2, along with the year. We now want to generate the plot to visualize the PCA.

# %%
#Generating a list of shorter names for the columns, so that the final visualization is less cluttered.
feature_names_short = [
    'Temp (°C)',
    'DO (mg/L)',
    'Salinity (psu)',
    'pH',
    'Secchi (ft)',
    'ChlA (µg/L)',
    'P (mg/L)',
    'NH4 (mg/L)',
    'TKN (mg/L)',
    'NO3+NO2 (mg/L)'
]

# %%
# Generating the plot
fig, ax = plt.subplots(figsize=(10, 8))

# --- Plot yearly points ---
ax.scatter(feature_means_pca_df['PC1'], feature_means_pca_df['PC2'], color='#009E73', zorder=5, s=60)
for _, row in feature_means_pca_df.iterrows():
    ax.annotate(str(int(row.name)), xy=(row['PC1'], row['PC2']),
                xytext=(5, 5), textcoords='offset points',
                fontsize=9, color='#009E73', fontweight='bold')

# --- Scale factor for arrows (tune as needed) ---
scale = 2.0

# --- Plot loading arrows ---
for i, name in enumerate(feature_names_short):
    x, y = loadings[i, 0] * scale, loadings[i, 1] * scale
    ax.annotate('', xy=(x, y), xytext=(0, 0),
                arrowprops=dict(arrowstyle='->', color='navy', lw=1.8))
    ax.text(x * 1.1, y * 1.1, name, fontsize=9, color='navy', fontstyle='italic')

# --- Secondary axes for loading scale ---
ax_top = ax.twiny()  # shares y-axis, adds top x-axis
ax_right = ax.twinx()  # shares x-axis, adds right y-axis

# Set limits divided by scale factor to show true loading values
ax_top.set_xlim(ax.get_xlim()[0] / scale, ax.get_xlim()[1] / scale)
ax_right.set_ylim(ax.get_ylim()[0] / scale, ax.get_ylim()[1] / scale)

# Style the top axis
ax_top.set_xlabel('PC1 Loadings', fontsize=10, color='navy', labelpad=8)
ax_top.tick_params(axis='x', colors='navy', labelsize=8)

# Style the right axis
ax_right.set_ylabel('PC2 Loadings', fontsize=10, color='navy', labelpad=8)
ax_right.tick_params(axis='y', colors='navy', labelsize=8)

# --- Reference lines ---
ax.axhline(0, color='gray', linewidth=0.8, linestyle='--')
ax.axvline(0, color='gray', linewidth=0.8, linestyle='--')

# --- Labels ---
ax.set_xlabel(f'PC 1 (Explained Variance: {explained_variance[0] * 100:.2f}%)', fontsize=12)
ax.set_ylabel(f'PC 2 (Explained Variance: {explained_variance[1] * 100:.2f}%)', fontsize=12)
ax.set_title('PCA Biplot – Jamaica Bay Water Quality (Station N16)', fontsize=13)

# --- Legend ---
arrow_patch = mpatches.FancyArrow(0, 0, 0, 0, color='darkblue')
point_patch = mpatches.Patch(color='#009E73', label='Calendar Year')
ax.legend(handles=[
    plt.Line2D([0], [0], color='darkblue', marker=r'$\rightarrow$',
               markersize=12, label='Water Quality Parameter', linestyle='None'),
    plt.Line2D([0], [0], marker='o', color='#009E73',
               markersize=8, label='Calendar Year', linestyle='None')
], loc='upper right')

plt.tight_layout()
plt.savefig('jamaica_bay_pca_n16.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## K-Means Clustering

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
# plot the elbow visualization
inertiaVals1 = {}

for k in range(1, 15):
    kmeansK1 = KMeans(n_clusters=k, max_iter=1000).fit(feature_means)
    inertiaVals1[k] = kmeansK1.inertia_
plt.figure()
plt.plot(list(inertiaVals1.keys()), list(inertiaVals1.values()))
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
# Find optimal number of clusters
for k in range(2, 7):
    km = KMeans(n_clusters=k, random_state=42)
    labels = km.fit_predict(feature_means)
    score = silhouette_score(feature_means, labels)
    print(f"k={k}, silhouette score: {score:.3f}")
# Out:
# k=2, silhouette score: 0.183
# k=3, silhouette score: 0.140
# k=4, silhouette score: 0.145
# k=5, silhouette score: 0.100
# k=6, silhouette score: 0.104

# %% [markdown]
# Two and three clusters seem ideal. I will start by visualizing those.

# %%
# Use best k
kmeans = KMeans(n_clusters=2, random_state=42)
feature_means_pca_df['Cluster'] = kmeans.fit_predict(feature_means)
print(feature_means_pca_df[['Cluster']].sort_values('Cluster'))
# Out:
#       Cluster
# Date
# 1996        0
# 1997        0
# 1998        0
# 1999        0
# 2000        0
# 2003        0
# 2005        0
# 2004        0
# 2008        0
# 2009        0
# 2006        0
# 2007        0
# 2010        0
# 2011        0
# 2013        0
# 2012        0
# 2024        0
# 2002        1
# 2001        1
# 2014        1
# 2016        1
# 2017        1
# 2018        1
# 2015        1
# 2019        1
# 2020        1
# 2022        1
# 2021        1
# 2023        1

# %%
# Generating the plot – colored by cluster
fig, ax = plt.subplots(figsize=(10, 8))

cluster_colors = {0: '#009E73', 1: '#CC79A7'}

# --- Plot yearly points ---
for idx, row in feature_means_pca_df.iterrows():
    color = cluster_colors[row['Cluster']]
    ax.scatter(row['PC1'], row['PC2'], color=color, zorder=5, s=60)
    ax.annotate(str(int(idx)), xy=(row['PC1'], row['PC2']),
                xytext=(5, 5), textcoords='offset points',
                fontsize=9, color=color, fontweight='bold')

# --- Scale factor for arrows ---
scale = 2.0

# --- Plot loading arrows ---
for i, name in enumerate(feature_names_short):
    x, y = loadings[i, 0] * scale, loadings[i, 1] * scale
    ax.annotate('', xy=(x, y), xytext=(0, 0),
                arrowprops=dict(arrowstyle='->', color='navy', lw=1.8))
    ax.text(x * 1.1, y * 1.1, name, fontsize=9, color='navy', fontstyle='italic')

# --- Secondary axes for loading scale ---
ax_top = ax.twiny()  # shares y-axis, adds top x-axis
ax_right = ax.twinx()  # shares x-axis, adds right y-axis

# Set limits divided by scale factor to show true loading values
ax_top.set_xlim(ax.get_xlim()[0] / scale, ax.get_xlim()[1] / scale)
ax_right.set_ylim(ax.get_ylim()[0] / scale, ax.get_ylim()[1] / scale)

# Style the top axis
ax_top.set_xlabel('PC1 Loadings', fontsize=10, color='navy', labelpad=8)
ax_top.tick_params(axis='x', colors='navy', labelsize=8)

# Style the right axis
ax_right.set_ylabel('PC2 Loadings', fontsize=10, color='navy', labelpad=8)
ax_right.tick_params(axis='y', colors='navy', labelsize=8)

# --- Reference lines ---
ax.axhline(0, color='gray', linewidth=0.8, linestyle='--')
ax.axvline(0, color='gray', linewidth=0.8, linestyle='--')

# --- Labels ---
ax.set_xlabel(f'PC 1 (Explained Variance: {explained_variance[0] * 100:.2f}%)', fontsize=12)
ax.set_ylabel(f'PC 2 (Explained Variance: {explained_variance[1] * 100:.2f}%)', fontsize=12)
ax.set_title('PCA Biplot – Jamaica Bay Water Quality (Station N16)', fontsize=13)

# --- Legend ---
ax.legend(handles=[
    plt.Line2D([0], [0], color='darkblue', marker=r'$\rightarrow$',
               markersize=12, label='Water Quality Parameter', linestyle='None'),
    plt.Line2D([0], [0], marker='o', color='#009E73',
               markersize=8, label='Calendar Year (Cluster 0)', linestyle='None'),
    plt.Line2D([0], [0], marker='o', color='#CC79A7',
               markersize=8, label='Calendar Year (Cluster 1)', linestyle='None'),
], loc='upper right')

plt.tight_layout()
plt.savefig('jamaica_bay_pca_n16_2clusters.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Doing the same with 3 clusters

# %%
# Use best k
kmeans1 = KMeans(n_clusters=3, random_state=42)
feature_means_pca_df['Cluster'] = kmeans1.fit_predict(feature_means)
print(feature_means_pca_df[['Cluster']].sort_values('Cluster'))
# Out:
#       Cluster
# Date
# 1996        0
# 1997        0
# 1998        0
# 2010        0
# 2008        0
# 2006        0
# 2005        0
# 2004        0
# 2011        0
# 2009        0
# 2024        0
# 2001        1
# 2014        1
# 2017        1
# 2015        1
# 2002        1
# 2023        1
# 2021        1
# 2022        1
# 2016        1
# 2018        1
# 2019        1
# 2020        1
# 2003        2
# 2007        2
# 1999        2
# 2000        2
# 2012        2
# 2013        2

# %%
# PCA biplot with 3 clusters, colored by cluster
fig, ax = plt.subplots(figsize=(10, 8))

cluster_colors = {0: '#009E73', 1: '#CC79A7', 2: '#56B4E9'}

# --- Plot yearly points ---
for idx, row in feature_means_pca_df.iterrows():
    color = cluster_colors[row['Cluster']]
    ax.scatter(row['PC1'], row['PC2'], color=color, zorder=5, s=60)
    ax.annotate(str(int(idx)), xy=(row['PC1'], row['PC2']),
                xytext=(5, 5), textcoords='offset points',
                fontsize=9, color=color, fontweight='bold')

# --- Scale factor for arrows ---
scale = 2.0

# --- Plot loading arrows ---
for i, name in enumerate(feature_names_short):
    x, y = loadings[i, 0] * scale, loadings[i, 1] * scale
    ax.annotate('', xy=(x, y), xytext=(0, 0),
                arrowprops=dict(arrowstyle='->', color='navy', lw=1.8))
    ax.text(x * 1.1, y * 1.1, name, fontsize=9, color='navy', fontstyle='italic')

# --- Secondary axes for loading scale ---
ax_top = ax.twiny()  # shares y-axis, adds top x-axis
ax_right = ax.twinx()  # shares x-axis, adds right y-axis

# Set limits divided by scale factor to show true loading values
ax_top.set_xlim(ax.get_xlim()[0] / scale, ax.get_xlim()[1] / scale)
ax_right.set_ylim(ax.get_ylim()[0] / scale, ax.get_ylim()[1] / scale)

# Style the top axis
ax_top.set_xlabel('PC1 Loadings', fontsize=10, color='navy', labelpad=8)
ax_top.tick_params(axis='x', colors='navy', labelsize=8)

# Style the right axis
ax_right.set_ylabel('PC2 Loadings', fontsize=10, color='navy', labelpad=8)
ax_right.tick_params(axis='y', colors='navy', labelsize=8)

# --- Reference lines ---
ax.axhline(0, color='gray', linewidth=0.8, linestyle='--')
ax.axvline(0, color='gray', linewidth=0.8, linestyle='--')

# --- Labels ---
ax.set_xlabel(f'PC 1 (Explained Variance: {explained_variance[0] * 100:.2f}%)', fontsize=12)
ax.set_ylabel(f'PC 2 (Explained Variance: {explained_variance[1] * 100:.2f}%)', fontsize=12)
ax.set_title('PCA Biplot – Jamaica Bay Water Quality (Station N16)', fontsize=13)

# --- Legend ---
ax.legend(handles=[
    plt.Line2D([0], [0], color='darkblue', marker=r'$\rightarrow$',
               markersize=12, label='Water Quality Parameter', linestyle='None'),
    plt.Line2D([0], [0], marker='o', color='#009E73',
               markersize=8, label='Calendar Year (Cluster 0)', linestyle='None'),
    plt.Line2D([0], [0], marker='o', color='#CC79A7',
               markersize=8, label='Calendar Year (Cluster 1)', linestyle='None'),
    plt.Line2D([0], [0], marker='o', color='#56B4E9',
               markersize=8, label='Calendar Year (Cluster 2)', linestyle='None'),
], loc='upper right')

plt.tight_layout()
plt.savefig('jamaica_bay_pca_n16_3clusters.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Initialize a new PCA with all components to get full explained variance
pca_full = PCA()
pca_full.fit(feature_means)

print("Explained Variance by Principal Component:")
for i, var in enumerate(pca_full.explained_variance_ratio_):
    print(f"  PC{i+1}: {var:.4f} ({var * 100:.2f}%)")
print(f"\nTotal explained variance: {sum(pca_full.explained_variance_ratio_):.4f} ({sum(pca_full.explained_variance_ratio_) * 100:.2f}%)")
# Out:
# Explained Variance by Principal Component:
#   PC1: 0.2820 (28.20%)
#   PC2: 0.2447 (24.47%)
#   PC3: 0.1469 (14.69%)
#   PC4: 0.0861 (8.61%)
#   PC5: 0.0845 (8.45%)
#   PC6: 0.0614 (6.14%)
#   PC7: 0.0392 (3.92%)
#   PC8: 0.0316 (3.16%)
#   PC9: 0.0195 (1.95%)
#   PC10: 0.0040 (0.40%)
#
# Total explained variance: 1.0000 (100.00%)

# %% [markdown]
# ## 3D Visualization

# %%
import plotly.graph_objects as go

pca3 = PCA(n_components=3)
pca3_coords = pca3.fit_transform(feature_means)
loadings3 = pca3.components_.T  # shape: (n_features, 3)

ev3 = pca3.explained_variance_ratio_
print(f"PC1: {ev3[0]*100:.2f}%  PC2: {ev3[1]*100:.2f}%  PC3: {ev3[2]*100:.2f}%  Total: {sum(ev3)*100:.2f}%")

pca3_df = pd.DataFrame(pca3_coords, columns=['PC1', 'PC2', 'PC3'], index=feature_means.index)
# Out:
# PC1: 28.20%  PC2: 24.47%  PC3: 14.69%  Total: 67.36%

# %%
cluster_colors = {0: '#009E73', 1: '#CC79A7', 2: '#56B4E9'}
cluster_labels = {0: 'Cluster 0', 1: 'Cluster 1', 2: 'Cluster 2'}
scale = 2.5

fig = go.Figure()

# Year scatter points colored by cluster
for cluster_id, color in cluster_colors.items():
    mask = feature_means_pca_df['Cluster'] == cluster_id
    subset = pca3_df[mask]
    fig.add_trace(go.Scatter3d(
        x=subset['PC1'], y=subset['PC2'], z=subset['PC3'],
        mode='markers+text',
        text=[str(y) for y in subset.index],
        textposition='top center',
        marker=dict(size=6, color=color),
        name=cluster_labels[cluster_id]
    ))

# Loading arrows
for i, name in enumerate(feature_names_short):
    lx, ly, lz = loadings3[i, 0] * scale, loadings3[i, 1] * scale, loadings3[i, 2] * scale
    fig.add_trace(go.Scatter3d(
        x=[0, lx], y=[0, ly], z=[0, lz],
        mode='lines',
        line=dict(color='navy', width=3),
        showlegend=False
    ))
    fig.add_trace(go.Scatter3d(
        x=[lx * 1.1], y=[ly * 1.1], z=[lz * 1.1],
        mode='text',
        text=[name],
        textfont=dict(color='navy', size=10),
        showlegend=False
    ))

fig.update_layout(
    title='3D PCA Biplot – Jamaica Bay Water Quality (Station N16)',
    scene=dict(
        xaxis_title=f'PC1 ({ev3[0]*100:.1f}%)',
        yaxis_title=f'PC2 ({ev3[1]*100:.1f}%)',
        zaxis_title=f'PC3 ({ev3[2]*100:.1f}%)',
    ),
    width=900,
    height=750
)

fig.show()
fig.write_html('n16_pca_3d.html')

# %%
cluster_colors = {0: '#009E73', 1: '#CC79A7', 2: '#56B4E9'}
cluster_labels = {0: 'Cluster 0', 1: 'Cluster 1', 2: 'Cluster 2'}
scale = 2.5
sorted_years = sorted(pca3_df.index.tolist())

fig = go.Figure()

# Initial state: first year only
for cluster_id, color in cluster_colors.items():
    mask = (feature_means_pca_df['Cluster'] == cluster_id) & (pca3_df.index <= sorted_years[0])
    subset = pca3_df[mask]
    fig.add_trace(go.Scatter3d(
        x=subset['PC1'], y=subset['PC2'], z=subset['PC3'],
        mode='markers+text',
        text=[str(y) for y in subset.index],
        textposition='top center',
        marker=dict(size=6, color=color),
        name=cluster_labels[cluster_id]
    ))

# Loading arrows — static, not animated
for i, name in enumerate(feature_names_short):
    lx, ly, lz = loadings3[i, 0] * scale, loadings3[i, 1] * scale, loadings3[i, 2] * scale
    fig.add_trace(go.Scatter3d(
        x=[0, lx], y=[0, ly], z=[0, lz],
        mode='lines',
        line=dict(color='navy', width=3),
        showlegend=False
    ))
    fig.add_trace(go.Scatter3d(
        x=[lx * 1.1], y=[ly * 1.1], z=[lz * 1.1],
        mode='text',
        text=[name],
        textfont=dict(color='navy', size=10),
        showlegend=False
    ))

# Animation frames: cumulative reveal by year
frames = []
for year in sorted_years:
    frame_traces = []
    for cluster_id, color in cluster_colors.items():
        mask = (feature_means_pca_df['Cluster'] == cluster_id) & (pca3_df.index <= year)
        subset = pca3_df[mask]
        frame_traces.append(go.Scatter3d(
            x=subset['PC1'], y=subset['PC2'], z=subset['PC3'],
            mode='markers+text',
            text=[str(y) for y in subset.index],
            textposition='top center',
            marker=dict(size=6, color=color)
        ))
    frames.append(go.Frame(data=frame_traces, name=str(year), traces=[0, 1, 2]))

fig.frames = frames

fig.update_layout(
    title='3D PCA Biplot – Jamaica Bay Water Quality (Station N16)',
    scene=dict(
        xaxis_title=f'PC1 ({ev3[0]*100:.1f}%)',
        yaxis_title=f'PC2 ({ev3[1]*100:.1f}%)',
        zaxis_title=f'PC3 ({ev3[2]*100:.1f}%)',
    ),
    sliders=[{
        'active': 0,
        'steps': [
            {
                'args': [[str(year)], {'frame': {'duration': 300, 'redraw': True}, 'mode': 'immediate'}],
                'label': str(year),
                'method': 'animate'
            }
            for year in sorted_years
        ],
        'currentvalue': {'prefix': 'Show years up to: ', 'visible': True, 'xanchor': 'center'},
        'pad': {'t': 50},
        'len': 0.9,
        'x': 0.05
    }],
    width=900,
    height=800
)

fig.show()
fig.write_html('n16_pca_3d_slider.html')
